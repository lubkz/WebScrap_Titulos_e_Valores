# %%
import requests
from bs4 import BeautifulSoup

print("INICIANDO...")

url = 'https://books.toscrape.com/'

response = requests.get(url)

if response.status_code == 200:
    print("Site carregado")
else:
    print("Erro")

soup = BeautifulSoup(response.text, "html.parser")

livros = soup.find_all("article", class_= "product_pod")

for livro in livros:
    titulo = livro.find("h3").find("a")["title"]
    preco = livro.find("p", class_= "price_color").text

    print(f"Titulo: {titulo}, Preço: {preco}")
print("FIM")
# Out:
# INICIANDO...
# Site carregado
# Titulo: A Light in the Attic, Preço: Â£51.77
# Titulo: Tipping the Velvet, Preço: Â£53.74
# Titulo: Soumission, Preço: Â£50.10
# Titulo: Sharp Objects, Preço: Â£47.82
# Titulo: Sapiens: A Brief History of Humankind, Preço: Â£54.23
# Titulo: The Requiem Red, Preço: Â£22.65
# Titulo: The Dirty Little Secrets of Getting Your Dream Job, Preço: Â£33.34
# Titulo: The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull, Preço: Â£17.93
# Titulo: The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics, Preço: Â£22.60
# Titulo: The Black Maria, Preço: Â£52.15
# Titulo: Starving Hearts (Triangular Trade Trilogy, #1), Preço: Â£13.99
# Titulo: Shakespeare's Sonnets, Preço: Â£20.66
# Titulo: Set Me Free, Preço: Â£17.46
# Titulo: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1), Preço: Â£52.29
# Titulo: Rip it Up and Start Again, Preço: Â£35.02
# Titulo: Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991, Preço: Â£57.25
# Titulo: Olio, Preço: Â£23.88
# Titulo: Mesaerion: The Best Science Fiction Stories 1800-1849, Preço: Â£37.59
# Titulo: Libertarianism for Beginners, Preço: Â£51.33
# Titulo: It's Only the Himalayas, Preço: Â£45.17
# FIM
